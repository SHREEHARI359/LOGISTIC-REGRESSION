# %%
import pandas as py
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=py.read_csv("social.csv")

# %%
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
X=dataset.iloc[:,:-1]

# %%
X
# Out:
#       User ID  Gender  Age  EstimatedSalary
# 0    15624510    Male   19            19000
# 1    15810944    Male   35            20000
# 2    15668575  Female   26            43000
# 3    15603246  Female   27            57000
# 4    15804002    Male   19            76000
# ..        ...     ...  ...              ...
# 395  15691863  Female   46            41000
# 396  15706071    Male   51            23000
# 397  15654296  Female   50            20000
# 398  15755018    Male   36            33000
# 399  15594041  Female   49            36000
#
# [400 rows x 4 columns]

# %%
Y=dataset.iloc[:,-1]

# %%
Y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 395    1
# 396    1
# 397    1
# 398    0
# 399    1
# Name: Purchased, Length: 400, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.25,random_state=0)

# %%
income=dataset['Gender']
dataset['Gender']=dataset['Gender'].map({'Female':1,'Male':0})

# %%
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510       0   19            19000          0
# 1    15810944       0   35            20000          0
# 2    15668575       1   26            43000          0
# 3    15603246       1   27            57000          0
# 4    15804002       0   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863       1   46            41000          1
# 396  15706071       0   51            23000          1
# 397  15654296       1   50            20000          1
# 398  15755018       0   36            33000          0
# 399  15594041       1   49            36000          1
#
# [400 rows x 5 columns]

# %%
dataset.head(10)
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510       0   19            19000          0
# 1  15810944       0   35            20000          0
# 2  15668575       1   26            43000          0
# 3  15603246       1   27            57000          0
# 4  15804002       0   19            76000          0
# 5  15728773       0   27            58000          0
# 6  15598044       1   27            84000          0
# 7  15694829       1   32           150000          1
# 8  15600575       0   25            33000          0
# 9  15727311       1   35            65000          0

# %%
X=dataset.iloc[:,:-1]
X
# Out:
#       User ID  Gender  Age  EstimatedSalary
# 0    15624510       0   19            19000
# 1    15810944       0   35            20000
# 2    15668575       1   26            43000
# 3    15603246       1   27            57000
# 4    15804002       0   19            76000
# ..        ...     ...  ...              ...
# 395  15691863       1   46            41000
# 396  15706071       0   51            23000
# 397  15654296       1   50            20000
# 398  15755018       0   36            33000
# 399  15594041       1   49            36000
#
# [400 rows x 4 columns]

# %%
X.columns[X.isna().any()]
# Out:
# Index([], dtype='object')

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.25,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.fit_transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
X
# Out:
#       User ID  Gender  Age  EstimatedSalary
# 0    15624510       0   19            19000
# 1    15810944       0   35            20000
# 2    15668575       1   26            43000
# 3    15603246       1   27            57000
# 4    15804002       0   19            76000
# ..        ...     ...  ...              ...
# 395  15691863       1   46            41000
# 396  15706071       0   51            23000
# 397  15654296       1   50            20000
# 398  15755018       0   36            33000
# 399  15594041       1   49            36000
#
# [400 rows x 4 columns]

# %%
Y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 395    1
# 396    1
# 397    1
# 398    0
# 399    1
# Name: Purchased, Length: 400, dtype: int64

# %%
dataset.columns
# Out:
# Index(['User ID', 'Gender', 'Age', 'EstimatedSalary', 'Purchased'], dtype='object')

# %%
User_ID=int(input("Enter User ID:"))
Gender=int(input("Enter Gender:"))
Age=int(input("Enter Age:"))
EstimatedSalary=int(input("Enter EstimatedSalary:"))
Released=[[Gender,Age,EstimatedSalary,User_ID]]
# Out:
# Enter User ID:15600575
# Enter Gender:0
# Enter Age:25
# Enter EstimatedSalary:33000

# %%
prediction = model.predict(sc.transform(Released))
print(prediction)
# Out:
# [1]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
sns.scatterplot(data=dataset,x="EstimatedSalary",y="Age",hue="EstimatedSalary",markers={"Male":"s","Female":"o"})
# Out:
# <Axes: xlabel='EstimatedSalary', ylabel='Age'>

# %%
sns.relplot(data=dataset,kind="scatter",x="Age",y="EstimatedSalary",col="Gender")

# %%
sns.displot(data=dataset, x="Age", y="EstimatedSalary", col="Gender", kind="kde")

# %%
Y_pred=model.predict(X_test)
from sklearn.metrics import accuracy_score
print("Accuarcy:{0}%".format(accuracy_score(Y_test,Y_pred)*100))
# Out:
# Accuarcy:90.0%
